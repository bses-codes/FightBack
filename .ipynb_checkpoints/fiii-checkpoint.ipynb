# %%
import pandas as pd

# %%
import random
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Data.csv",index_col=0)

# %%
df.head(10)
# Out:
#                                                              Source  \
# Reference number
# CH14QV99NQ        http://thehimalayantimes.com/fullNews.php?head...
# XJ99BF74EC        http://nepalpolice.gov.np/%E0%A4%9C%E0%A4%B5%E...
# IG49WH92XY        http://nepalpolice.gov.np/2013-05-02-10-32-36....
# IS62NJ41RL        http://nepalpolice.gov.np/2013-05-07-10-39-08....
# ZP39BS50LY        http://thehimalayantimes.com/fullNews.php?head...
# LP22DS72LE        http://thehimalayantimes.com/fullNews.php?head...
# MA88GP02AH        http://nepalpolice.gov.np/2013-06-09-10-53-36....
# XT54XX52NQ        http://nepalpolice.gov.np/2013-06-19-11-52-51....
# LT42OQ97BA        http://nepalpolice.gov.np/2013-06-21-09-27-17....
# WC76RN52WN        http://thehimalayantimes.com/fullNews.php?head...
#
#                                            Description of Incidents  \
# Reference number
# CH14QV99NQ        An 18-year-old youth was arrested March 25 on ...
# XJ99BF74EC        Police had taken under control Hitman Shahi (4...
# IG49WH92XY        Fourteen year old Devendra Rana and eleven yea...
# IS62NJ41RL        Police on 07 May arrested Dharmaraj Jamarkatte...
# ZP39BS50LY        Police on 08 May arrested Bhakta Bahadur Blon ...
# LP22DS72LE        Police on 16 May arrested a 43-year-old man of...
# MA88GP02AH        Kamalesh Shah (15) of Sitamadi, India, current...
# XT54XX52NQ        The Metropolitan Police Circle, Kalimati, on 1...
# LT42OQ97BA        Police on 21 June had arrested Shyam Lal Shres...
# WC76RN52WN        Police on 27 June arrested a manager of the Ja...
#
#                  Type of Attack Attempted or Raped Who was it reported to  \
# Reference number
# CH14QV99NQ               Child           Molesting          Victim Father
# XJ99BF74EC               Child           Attempted                 Police
# IG49WH92XY                 Gang              Raped                 Police
# IS62NJ41RL               Child               Raped                 Police
# ZP39BS50LY          Opportunist              Raped                 Police
# LP22DS72LE          Opportunist          Attempted                 Police
# MA88GP02AH               Child               Raped                 Police
# XT54XX52NQ               Child               Raped                 Police
# LT42OQ97BA               Child               Raped                 Police
# WC76RN52WN          Opportunist              Raped                 Police
#
#                  Consequences of the attack Date of Incident  Districts  \
# Reference number
# CH14QV99NQ                 Physical Injury        25/03/2013  Kathmandu
# XJ99BF74EC                 Physical Injury        03/04/2013  Kathmandu
# IG49WH92XY                 Physical Injury        01/05/2013  Kathmandu
# IS62NJ41RL                 Physical Injury        07/05/2013  Kathmandu
# ZP39BS50LY                 Physical Injury        08/05/2013  Kathmandu
# LP22DS72LE                 Physical Injury        16/05/2013  Kathmandu
# MA88GP02AH                 Physical Injury        05/06/2013  Kathmandu
# XT54XX52NQ                 Physical Injury        19/06/2013  Kathmandu
# LT42OQ97BA                 Physical Injury        21/06/2013  Kathmandu
# WC76RN52WN                 Physical Injury        27/06/2013  Kathmandu
#
#                                     Geographical Region
# Reference number
# CH14QV99NQ          27.7199745185167, 85.32344429728326
# XJ99BF74EC          27.7199745185167, 85.32344429728326
# IG49WH92XY          27.7199745185167, 85.32344429728326
# IS62NJ41RL          27.7199745185167, 85.32344429728326
# ZP39BS50LY          27.7199745185167, 85.32344429728326
# LP22DS72LE          27.7199745185167, 85.32344429728326
# MA88GP02AH          27.7199745185167, 85.32344429728326
# XT54XX52NQ          27.7199745185167, 85.32344429728326
# LT42OQ97BA          27.55752119624532, 85.0217998274353
# WC76RN52WN        26.854997689608705, 86.66093541143567

# %% [markdown]
# ### Impact Assesment: Analysis of the "Consequences of the attack " column to understand the impacts on survivors and their communities.This can hilight the need for support systems and rehabilitation services.

# %%
district_grp = pd.DataFrame(df.groupby(['Districts']).size())
district_grp.columns = ['Districts']
district_grp
# Out:
#                Districts
# Districts
# Achham                 5
# Arghakhanchi           9
# Baglung               16
# Baitadi               14
# Bajhang                9
# ...                  ...
# Udaypur                1
# Udhayapur              6
# Western Rukum          1
# parsa                  2
# sunsari                1
#
# [149 rows x 1 columns]

# %%
consequences_counts = df['Consequences of the attack'].value_counts()

# %%
df["Consequences of the attack"].unique()
# Out:
# array(['Physical Injury ', 'Physical injury ', 'Physical injury',
#        'mentally ill', 'Murder', 'Physical Injury', 'Pregnant',
#        'physical Injury', 'pregnant ', 'death', 'murder', 'Murdered',
#        'Physical Attack', ' pregnent', nan, ' Physical Injury ',
#        ' murder', 'pregnant'], dtype=object)

# %%
df["Consequences of the attack"]=df["Consequences of the attack"].str.lower()
df["Consequences of the attack"]=df["Consequences of the attack"].str.strip()
df["Consequences of the attack"]=df["Consequences of the attack"].str.replace("murdered","murder")
df["Consequences of the attack"]=df["Consequences of the attack"].str.replace("physical attack","physical Injury")
df["Consequences of the attack"]=df["Consequences of the attack"].str.replace("pregnent","pregnant")
df["Consequences of the attack"]=df["Consequences of the attack"].str.replace("dearth","death")
df["Consequences of the attack"]=df["Consequences of the attack"].str.replace("mantally ill","Mentally ill")
df["Consequences of the attack"]=df["Consequences of the attack"].str.replace("physical injury","physical Injury")

# %%
df["Consequences of the attack"].unique()
# Out:
# array(['physical Injury', 'mentally ill', 'murder', 'pregnant', 'death',
#        nan], dtype=object)

# %%
len(df["Districts"].unique())
# Out:
# 150

# %%
df["Districts"]=df["Districts"].str.lower()
df["Districts"]=df["Districts"].str.strip()
df["Districts"]=df["Districts"].str.replace("kaverepalanchowk","kavrepalanchok")
df["Districts"]=df["Districts"].str.replace("sunsary","sunsari")
df["Districts"]=df["Districts"].str.replace("rupendhi","rupandehi")
df["Districts"]=df["Districts"].str.replace("terahathum","terhathum")
df["Districts"]=df["Districts"].str.replace("solukhubmu","solukhumbu")
df["Districts"]=df["Districts"].str.replace("tehrathum","terhathum")
df["Districts"]=df["Districts"].str.replace("terathum","terhathum")
df["Districts"]=df["Districts"].str.replace("rupandahi","rupandehi")
df["Districts"]=df["Districts"].str.replace("rupandhi","rupandehi")
df["Districts"]=df["Districts"].str.replace("sindupalchok","sindhupalchowk")
df["Districts"]=df["Districts"].str.replace("sindupalchowk","sindhupalchowk")
df["Districts"]=df["Districts"].str.replace("sindhupalachok","sindhupalchowk")
df["Districts"]=df["Districts"].str.replace("sindhhupalchok","sindhupalchowk")
df["Districts"]=df["Districts"].str.replace("sindhupalchok","sindhupalchowk")
df["Districts"]=df["Districts"].str.replace("sindhuplchwok","sindhupalchowk")
df["Districts"]=df["Districts"].str.replace("sindhuplchowk","sindhupalchowk")
df["Districts"]=df["Districts"].str.replace("sindhupalchwok","sindhupalchowk")
df["Districts"]=df["Districts"].str.replace("mohattari","mahottari")
df["Districts"]=df["Districts"].str.replace("ruoendehi","rupandehi")
df["Districts"]=df["Districts"].str.replace("rupendehi","rupandehi")
df["Districts"]=df["Districts"].str.replace("western rukum","rukum")
df["Districts"]=df["Districts"].str.replace("rukum west, karnali","rukum")
df["Districts"]=df["Districts"].str.replace("rukum \(west\)","rukum")
df["Districts"]=df["Districts"].str.replace("rukum west","rukum")
df["Districts"]=df["Districts"].str.replace("rukum east","rukum")
df["Districts"]=df["Districts"].str.replace("kabhrepalanchok","kavre")
df["Districts"]=df["Districts"].str.replace("kavrepalanchock","kavre")
df["Districts"]=df["Districts"].str.replace("kaverepalanchok","kavre")
df["Districts"]=df["Districts"].str.replace("kavrepalanchok","kavre")
df["Districts"]=df["Districts"].str.replace("bhojur","bhojpur")
df["Districts"]=df["Districts"].str.replace("sayangja","syangja")
df["Districts"]=df["Districts"].str.replace("sayanja","syangja")
df["Districts"]=df["Districts"].str.replace("panchathar","panchthar")
df["Districts"]=df["Districts"].str.replace("pachthar","panchthar")
df["Districts"]=df["Districts"].str.replace("tahanu","tanahu")
df["Districts"]=df["Districts"].str.replace("tanahun","tanahu")
df["Districts"]=df["Districts"].str.replace("udhayapur","udayapur")
df["Districts"]=df["Districts"].str.replace("udaypur","udayapur")
df["Districts"]=df["Districts"].str.replace("udaipur","udayapur")
df["Districts"]=df["Districts"].str.replace("ilam","illam")
df["Districts"]=df["Districts"].str.replace("kapilbastu","kapilvastu")
df["Districts"]=df["Districts"].str.replace("bardia","bardiya")
df["Districts"]=df["Districts"].str.replace("dailekh","dailekh")
df["Districts"]=df["Districts"].str.replace("taplegunj","taplejung")
df["Districts"]=df["Districts"].str.replace("dolkha","dolakha")
df["Districts"]=df["Districts"].str.replace("nawaparasi west","nawalparasi")
df["Districts"]=df["Districts"].str.replace("nawalparasi west","nawalparasi")
df["Districts"]=df["Districts"].str.replace("nawalparasi east","nawalparasi")
df["Districts"]=df["Districts"].str.replace("pratappur","nawalparasi")
df["Districts"]=df["Districts"].str.replace("sapatari","saptari")
df["Districts"]=df["Districts"].str.replace("chitawan","chitwan")
df["Districts"]=df["Districts"].str.replace("solukhumbhu","solukhumbu")
df["Districts"]=df["Districts"].str.replace("solukhubmu","solukhumbu")
df["Districts"]=df["Districts"].str.replace("shankhuwasabha","sankhuwasabha")
df["Districts"]=df["Districts"].str.replace("bakya","banke")
df["Districts"]=df["Districts"].str.replace("rampur, palpa","palpa")
df["Districts"]=df["Districts"].str.replace("gandaki, parbat","parbat")
df["Districts"]=df["Districts"].str.replace("gandaki, myagdi","myagdi")
df["Districts"]=df["Districts"].str.replace("karnali, dailekh","dailekh")
df["Districts"]=df["Districts"].str.replace("mades,bara","bara")
df["Districts"]=df["Districts"].str.replace("kritipur","kathmandu")
df["Districts"]=df["Districts"].str.replace("okheldunga","okhaldhunga")
df["Districts"]=df["Districts"].str.replace("mades,bara","bara")
df["Districts"]=df["Districts"].str.replace("birgunj","parsa")
df["Districts"]=df["Districts"].str.replace("hetauda","makwanpur")
df["Districts"]=df["Districts"].str.replace("pokhara","kaski")
df["Districts"]=df["Districts"].str.replace("itahari","sunsari")
df["Districts"]=df["Districts"].str.replace("lumbini","rupandehi")
df["Districts"]=df["Districts"].str.replace("dharan","sunsari")
df["Districts"]=df["Districts"].str.replace("bardibas","mahottari")
df["Districts"]=df["Districts"].str.replace("dhanusha","dhanusa")
df["Districts"]=df["Districts"].str.replace("madi","chitwan")
# Out:
# C:\Users\Bishesh Kafle\AppData\Local\Temp\ipykernel_7112\2300343643.py:25: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["Districts"]=df["Districts"].str.replace("rukum \(west\)","rukum")

# %%
df[df["Districts"] == 'sudurpachim']
# Out:
#                                                              Source  \
# Reference number
# SS16MI03XR        https://pahilopost.com/content/20210715085231....
#
#                                            Description of Incidents  \
# Reference number
# SS16MI03XR        Maya, a 15-year-old girl with intellectual dis...
#
#                  Type of Attack Attempted or Raped Who was it reported to  \
# Reference number
# SS16MI03XR                Child              Raped                 Police
#
#                  Consequences of the attack Date of Incident    Districts  \
# Reference number
# SS16MI03XR                  physical Injury       15/07/2021  sudurpachim
#
#                  Geographical Region
# Reference number
# SS16MI03XR                       NaN

# %%
df["Districts"].unique()
# Out:
# array(['kathmandu', 'siraha', 'jhapa', 'rautahat', 'mahottari', 'sunsari',
#        'rupandehi', 'morang', 'sindhupalchowk', 'khotang', 'rukum',
#        'palpa', 'lamjung', 'gulmi', 'kavre', 'kaski', 'banke', 'bara',
#        'bhaktapur', 'pyuthan', 'sarlahi', 'bhojpur', 'terhathum', 'dang',
#        'syangja', 'kailali', 'kanchanpur', 'gorkha', 'dadeldhura',
#        'dhanusa', 'panchthar', 'sindhuli', 'tanahu', 'udayapur',
#        'makwanpur', 'illam', 'rasuwa', 'kapilvastu', 'baglung', 'bardiya',
#        'jajarkot', 'lalitpur', 'dailekh', 'myagdi', 'arghakhanchi',
#        'taplejung', 'dolakha', 'nawalparasi', 'darchula', 'salyan',
#        'surkhet', 'parsa', 'parbat', 'saptari', 'kalikot', 'chitwan',
#        'baitadi', 'bajura', 'nuwakot', 'bajhang', 'jumla', 'solukhumbu',
#        'mugu', 'dhading', 'dhankuta', 'doti', 'achham', 'okhaldhunga',
#        'ramechhap', 'mustang', 'dolpa', 'sankhuwasabha', nan, 'humla',
#        'rolpa', 'manang', 'sudurpachim'], dtype=object)

# %%
len(df["Districts"].unique())
# Out:
# 77

# %%
df
# Out:
#                                                              Source  \
# Reference number
# CH14QV99NQ        http://thehimalayantimes.com/fullNews.php?head...
# XJ99BF74EC        http://nepalpolice.gov.np/%E0%A4%9C%E0%A4%B5%E...
# IG49WH92XY        http://nepalpolice.gov.np/2013-05-02-10-32-36....
# IS62NJ41RL        http://nepalpolice.gov.np/2013-05-07-10-39-08....
# ZP39BS50LY        http://thehimalayantimes.com/fullNews.php?head...
# ...                                                             ...
# VQ02QJ16IA              https://nepalmonitor.org/reports/view/41875
# OS92RX27HN                    https://nepalpolice.gov.np/news/3741/
# LW75CB63DB                    https://nepalpolice.gov.np/news/3746/
# KH48LW89IO                    https://nepalpolice.gov.np/news/3767/
# HH53FD93DS              https://nepalmonitor.org/reports/view/41911
#
#                                            Description of Incidents  \
# Reference number
# CH14QV99NQ        An 18-year-old youth was arrested March 25 on ...
# XJ99BF74EC        Police had taken under control Hitman Shahi (4...
# IG49WH92XY        Fourteen year old Devendra Rana and eleven yea...
# IS62NJ41RL        Police on 07 May arrested Dharmaraj Jamarkatte...
# ZP39BS50LY        Police on 08 May arrested Bhakta Bahadur Blon ...
# ...                                                             ...
# VQ02QJ16IA        One person has been arrested on charges of rap...
# OS92RX27HN        Baglung, a 17-year-old boy living in Nisikhola...
# LW75CB63DB        Jhapa, 31-year-old Dhan Kumar Limbu, resident ...
# KH48LW89IO        Baglung, Police arrested 28-year-old Bimal Ham...
# HH53FD93DS        Man arrested from Sankhuwasabha on the charge ...
#
#                  Type of Attack Attempted or Raped Who was it reported to  \
# Reference number
# CH14QV99NQ               Child           Molesting          Victim Father
# XJ99BF74EC               Child           Attempted                 Police
# IG49WH92XY                 Gang              Raped                 Police
# IS62NJ41RL               Child               Raped                 Police
# ZP39BS50LY          Opportunist              Raped                 Police
# ...                         ...                ...                    ...
# VQ02QJ16IA          Opportunist               Rape                 Police
# OS92RX27HN                Child               Rape                 Police
# LW75CB63DB          Opportunist               Rape                 Police
# KH48LW89IO          Opportunist               Rape                 Police
# HH53FD93DS          Opportunist               Rape                 Police
#
#                  Consequences of the attack Date of Incident      Districts  \
# Reference number
# CH14QV99NQ                  physical Injury       25/03/2013      kathmandu
# XJ99BF74EC                  physical Injury       03/04/2013      kathmandu
# IG49WH92XY                  physical Injury       01/05/2013      kathmandu
# IS62NJ41RL                  physical Injury       07/05/2013      kathmandu
# ZP39BS50LY                  physical Injury       08/05/2013      kathmandu
# ...                                     ...              ...            ...
# VQ02QJ16IA                  physical Injury       14/06/2023       lalitpur
# OS92RX27HN                  physical Injury       09/07/2023        baglung
# LW75CB63DB                  physical Injury       07/02/2023          jhapa
# KH48LW89IO                  physical Injury       12/07/2023        baglung
# HH53FD93DS                  physical Injury       12/07/2023  sankhuwasabha
#
#                                     Geographical Region
# Reference number
# CH14QV99NQ          27.7199745185167, 85.32344429728326
# XJ99BF74EC          27.7199745185167, 85.32344429728326
# IG49WH92XY          27.7199745185167, 85.32344429728326
# IS62NJ41RL          27.7199745185167, 85.32344429728326
# ZP39BS50LY          27.7199745185167, 85.32344429728326
# ...                                                 ...
# VQ02QJ16IA        27.662405818404125, 85.32435296718468
# OS92RX27HN         28.28119980900559, 83.58164488651326
# LW75CB63DB        26.577739181619766, 87.89718581504616
# KH48LW89IO         28.28104863825078, 83.58215987061996
# HH53FD93DS        27.676079840209752, 87.30574864049214
#
# [1925 rows x 9 columns]

# %%
df.dropna(inplace = True)

# %%
df.reset_index()
# Out:
#      Reference number                                             Source  \
# 0          CH14QV99NQ  http://thehimalayantimes.com/fullNews.php?head...
# 1          XJ99BF74EC  http://nepalpolice.gov.np/%E0%A4%9C%E0%A4%B5%E...
# 2          IG49WH92XY  http://nepalpolice.gov.np/2013-05-02-10-32-36....
# 3          IS62NJ41RL  http://nepalpolice.gov.np/2013-05-07-10-39-08....
# 4          ZP39BS50LY  http://thehimalayantimes.com/fullNews.php?head...
# ...               ...                                                ...
# 1898       VQ02QJ16IA        https://nepalmonitor.org/reports/view/41875
# 1899       OS92RX27HN              https://nepalpolice.gov.np/news/3741/
# 1900       LW75CB63DB              https://nepalpolice.gov.np/news/3746/
# 1901       KH48LW89IO              https://nepalpolice.gov.np/news/3767/
# 1902       HH53FD93DS        https://nepalmonitor.org/reports/view/41911
#
#                                Description of Incidents Type of Attack  \
# 0     An 18-year-old youth was arrested March 25 on ...         Child
# 1     Police had taken under control Hitman Shahi (4...         Child
# 2     Fourteen year old Devendra Rana and eleven yea...           Gang
# 3     Police on 07 May arrested Dharmaraj Jamarkatte...         Child
# 4     Police on 08 May arrested Bhakta Bahadur Blon ...    Opportunist
# ...                                                 ...            ...
# 1898  One person has been arrested on charges of rap...    Opportunist
# 1899  Baglung, a 17-year-old boy living in Nisikhola...          Child
# 1900  Jhapa, 31-year-old Dhan Kumar Limbu, resident ...    Opportunist
# 1901  Baglung, Police arrested 28-year-old Bimal Ham...    Opportunist
# 1902  Man arrested from Sankhuwasabha on the charge ...    Opportunist
#
#      Attempted or Raped Who was it reported to Consequences of the attack  \
# 0             Molesting          Victim Father            physical Injury
# 1             Attempted                 Police            physical Injury
# 2                 Raped                 Police            physical Injury
# 3                 Raped                 Police            physical Injury
# 4                 Raped                 Police            physical Injury
# ...                 ...                    ...                        ...
# 1898               Rape                 Police            physical Injury
# 1899               Rape                 Police            physical Injury
# 1900               Rape                 Police            physical Injury
# 1901               Rape                 Police            physical Injury
# 1902               Rape                 Police            physical Injury
#
#      Date of Incident      Districts                    Geographical Region
# 0          25/03/2013      kathmandu    27.7199745185167, 85.32344429728326
# 1          03/04/2013      kathmandu    27.7199745185167, 85.32344429728326
# 2          01/05/2013      kathmandu    27.7199745185167, 85.32344429728326
# 3          07/05/2013      kathmandu    27.7199745185167, 85.32344429728326
# 4          08/05/2013      kathmandu    27.7199745185167, 85.32344429728326
# ...               ...            ...                                    ...
# 1898       14/06/2023       lalitpur  27.662405818404125, 85.32435296718468
# 1899       09/07/2023        baglung   28.28119980900559, 83.58164488651326
# 1900       07/02/2023          jhapa  26.577739181619766, 87.89718581504616
# 1901       12/07/2023        baglung   28.28104863825078, 83.58215987061996
# 1902       12/07/2023  sankhuwasabha  27.676079840209752, 87.30574864049214
#
# [1903 rows x 10 columns]

# %%
count_data = df.groupby(['Date of Incident''Districts']).size().unstack(fill_value=0)

# %%
count_data
# Out:
# Districts         banke  bara  bardiya  bhaktapur  bhojpur  chitwan  dang  \
# Date of Incident
# 01/01/2016            0     0        0          0        0        0     0
# 01/01/2023            0     0        0          0        0        0     0
# 01/02/2016            0     0        0          0        0        0     0
# 01/02/2019            0     0        0          0        0        0     0
# 01/02/2020            0     0        0          0        0        0     0
# ...                 ...   ...      ...        ...      ...      ...   ...
# 31/08/2021            0     0        0          0        0        0     0
# 31/08/2022            0     0        0          0        0        0     0
# 31/10/2019            0     0        0          0        0        0     0
# 31/10/2021            0     0        0          0        0        0     0
# 31/12/2015            0     0        0          0        0        0     0
#
# Districts         dhanusa  gorkha  gulmi  ...  rautahat  rupandehi  saptari  \
# Date of Incident                          ...
# 01/01/2016              0       0      0  ...         0          0        0
# 01/01/2023              0       0      0  ...         0          0        0
# 01/02/2016              0       0      0  ...         1          0        0
# 01/02/2019              0       0      0  ...         0          0        0
# 01/02/2020              0       0      0  ...         0          0        1
# ...                   ...     ...    ...  ...       ...        ...      ...
# 31/08/2021              0       0      0  ...         1          1        0
# 31/08/2022              0       0      0  ...         0          0        0
# 31/10/2019              0       0      0  ...         0          0        0
# 31/10/2021              0       0      0  ...         0          0        0
# 31/12/2015              0       0      0  ...         0          0        0
#
# Districts         sarlahi  sindhupalchowk  siraha  sunsari  tanahu  terhathum  \
# Date of Incident
# 01/01/2016              0               0       0        0       0          0
# 01/01/2023              0               1       0        0       0          0
# 01/02/2016              0               0       0        0       0          0
# 01/02/2019              0               0       0        0       0          0
# 01/02/2020              0               0       0        0       0          0
# ...                   ...             ...     ...      ...     ...        ...
# 31/08/2021              0               0       0        0       0          0
# 31/08/2022              0               0       0        0       0          0
# 31/10/2019              0               0       0        0       0          0
# 31/10/2021              0               0       0        0       0          0
# 31/12/2015              0               0       0        0       0          0
#
# Districts         udayapur
# Date of Incident
# 01/01/2016               0
# 01/01/2023               0
# 01/02/2016               0
# 01/02/2019               1
# 01/02/2020               0
# ...                    ...
# 31/08/2021               1
# 31/08/2022               0
# 31/10/2019               0
# 31/10/2021               0
# 31/12/2015               0
#
# [1186 rows x 35 columns]

# %%
count_data.plot(kind='bar', stacked=True, figsize=(20, 6))
plt.xlabel('Districts')
plt.ylabel('Count')
plt.title('Occurrences of Consequences in each District')
plt.legend(title='Consequences', bbox_to_anchor=(1.05, 1), loc='upper left',facecolor="grey")
plt.show()

# %% [markdown]
# ##### From the bar graph above representing the consequences,we observe that the highest rate of occurrence is attributed to "physical injury".This indicates that survivors most commonly experience physical harm as a consequence of the crime,underlining the immediate and tangible impact on their well-being.In Kathmandu,the prevalence of consequences resulting from the data set is highest, with a notable emphasis on "Physical Injury"(almost no other consequences).
# #####  As of the current data, the districts of Manang and Rukum exhibit the lowest incidence of consequences arising from rape compared to the others.
# ##### Survivors often experience significant psychological and emotional trauma. Common psychological consequences include mental illness,anxiety, depression, post-traumatic stress disorder (PTSD), feelings of shame, guilt, fear, and self-blame. The emotional impact can be long-lasting and may require therapy and counseling for healing.And for this,Morang stands out as a district warranting attention. Similarly , we can observe other consequences in districts from the graph.

# %% [markdown]
# ##### Understanding the consequences of rape is crucial for policymakers, support organizations, and communities to provide vital assistance to survivors. It highlights the need for comprehensive measures, including better access to medical and mental health services, legal protection and justice, community awareness, and education. Prevention efforts must promote consent, healthy relationships, and gender equality to foster safer communities for all.

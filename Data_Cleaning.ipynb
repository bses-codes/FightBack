# %%
import pandas as pd

# %%
df = pd.read_csv("Data.csv")
df
# Out:
#      Reference number                                             Source  \
# 0          CH14QV99NQ  http://thehimalayantimes.com/fullNews.php?head...
# 1          XJ99BF74EC  http://nepalpolice.gov.np/%E0%A4%9C%E0%A4%B5%E...
# 2          IG49WH92XY  http://nepalpolice.gov.np/2013-05-02-10-32-36....
# 3          IS62NJ41RL  http://nepalpolice.gov.np/2013-05-07-10-39-08....
# 4          ZP39BS50LY  http://thehimalayantimes.com/fullNews.php?head...
# ...               ...                                                ...
# 2415       VQ02QJ16IA        https://nepalmonitor.org/reports/view/41875
# 2416       OS92RX27HN              https://nepalpolice.gov.np/news/3741/
# 2417       LW75CB63DB              https://nepalpolice.gov.np/news/3746/
# 2418       KH48LW89IO              https://nepalpolice.gov.np/news/3767/
# 2419       HH53FD93DS        https://nepalmonitor.org/reports/view/41911
#
#                                Description of Incidents Type of Attack  \
# ...

# %%
df["Sources"] = df['Source'].str.extract(r'[/(]([\w.]+)')

# %%
df
# Out:
#      Reference number                                             Source  \
# 0          CH14QV99NQ  http://thehimalayantimes.com/fullNews.php?head...
# 1          XJ99BF74EC  http://nepalpolice.gov.np/%E0%A4%9C%E0%A4%B5%E...
# 2          IG49WH92XY  http://nepalpolice.gov.np/2013-05-02-10-32-36....
# 3          IS62NJ41RL  http://nepalpolice.gov.np/2013-05-07-10-39-08....
# 4          ZP39BS50LY  http://thehimalayantimes.com/fullNews.php?head...
# ...               ...                                                ...
# 2415       VQ02QJ16IA        https://nepalmonitor.org/reports/view/41875
# 2416       OS92RX27HN              https://nepalpolice.gov.np/news/3741/
# 2417       LW75CB63DB              https://nepalpolice.gov.np/news/3746/
# 2418       KH48LW89IO              https://nepalpolice.gov.np/news/3767/
# 2419       HH53FD93DS        https://nepalmonitor.org/reports/view/41911
#
#                                Description of Incidents Type of Attack  \
# ...

# %% [markdown]
# Data cleaning took way longer then expected. Mostly the sources column. There were about 12+ different formats in which website or sources were stored and bringing them into a common representation was a huge task.

# %% [markdown]
# ***
# <b>Below are the unique sources extracted from all of the datasets.</b>

# %%
df[df["Sources"] =='com']
# Out:
#     Reference number                           Description of Incidents  \
# 45        HF99GL41DO  Police on 25 April made public four persons in...
# 57        AK42MD51TF  Purna Bahadur Gurung, 68, of Angding-9 of the ...
# 63        ZI10TP04HR  An 11-year-old girl was raped at her house in ...
# 66        DB70JU37ZS   Police have arrested Dhan Bahadur Gurung, 23,...
# 77        SD10BF49QT  Police had arrested  Pradip Shankar, 17, of Lu...
# 87        PB66OG02YD  A woman was reportedly gang-raped inside a tru...
# 93        WX60UF72IU  A 17-year-old girl has been raped in the distr...
# 95        HH99UV08OX  A ten-year-old girl was allegedly raped at Pip...
# 96        WY95FH37RG  A 14-year old Indian girl who was at her relat...
# 97        FD42QU03NW  A 19-year old girl of Majhouliya VDC-8 in the ...
# 107       TI72SK91PP  Dirgha Prasad Sherchan, a constable of the Arm...
# 112       LR20LR46HA  Police on 29 October had arrested an alleged r...
# ...

# %%
df["Sources"].unique()
# Out:
# array(['thehimalayantimes.com', 'nepalpolice.gov.np', 'com',
#        'ekantipur.com', nan, 'nepalnews.com', 'new.com',
#        'nepalmonitor.org', 'inseconline.org', 'nagariknetwork.com',
#        'annapurnapost.com', 'onlinekhabar.com', 'ratopati.com',
#        'myrepublica.com', 'ujyaaloonline.com', 'en', 'drive.google.com',
#        'khabarhub.com', 'rajdhanidaily.com', 'spotlightnepal.com',
#        'nepalipolice.gov.np', 'dineshkhabar.com', 'koshionline.com',
#        'nepalpolice.com.np', 'nayapatrikadaily.com', 'blastkhabar.com',
#        'kharibot.com', 'setopati.com', 'newsofnepal.com', 'nepalpati.com',
#        'news24nepal.tv', 'thahakhabar.com', 'saurahaonline.com',
#        'khabarbreak.com', 'thepublictoday.com', 'pahilopost.com',
#        'imagekhabar.com', 'baahrakhari.com', 'enewsbureau.com',
#        'nepallive.com', 'accounts.google.com', 'khabarcenter.com',
#        'nepalkhabar.com', 'nepalpress.com', 'setokhari.com',
# ...

# %% [markdown]
# Remove the original source column

# %%
df = df.drop('Source',axis = 1)

# %%
df
# Out:
#      Reference number                           Description of Incidents  \
# 0          CH14QV99NQ  An 18-year-old youth was arrested March 25 on ...
# 1          XJ99BF74EC  Police had taken under control Hitman Shahi (4...
# 2          IG49WH92XY  Fourteen year old Devendra Rana and eleven yea...
# 3          IS62NJ41RL  Police on 07 May arrested Dharmaraj Jamarkatte...
# 4          ZP39BS50LY  Police on 08 May arrested Bhakta Bahadur Blon ...
# ...               ...                                                ...
# 2415       VQ02QJ16IA  One person has been arrested on charges of rap...
# 2416       OS92RX27HN  Baglung, a 17-year-old boy living in Nisikhola...
# 2417       LW75CB63DB  Jhapa, 31-year-old Dhan Kumar Limbu, resident ...
# 2418       KH48LW89IO  Baglung, Police arrested 28-year-old Bimal Ham...
# 2419       HH53FD93DS  Man arrested from Sankhuwasabha on the charge ...
#
#      Type of Attack Attempted or Raped Who was it reported to  \
# ...

# %%
df['Consequences of the attack'].unique()
# Out:
# array(['Physical Injury ', 'Physical injury ', 'Physical injury',
#        'Mantally ill', 'Murder', 'Physical Injury', 'Pregnant',
#        'physical Injury', 'pregnant ', 'Dearth', 'Murdered',
#        'Physical Attack', 'Muder', ' pregnent', 'pregnant', nan,
#        ' Physical Injury ', ' Murdered'], dtype=object)

# %%
df['Consequences of the attack'] = df['Consequences of the attack'].str.lower()
df['Consequences of the attack'] = df['Consequences of the attack'].str.strip()

# %%
df['Consequences of the attack'] = df['Consequences of the attack'].str.replace('murdered','murder')
df['Consequences of the attack'] = df['Consequences of the attack'].str.replace('physical attack','physical injury')
df['Consequences of the attack'] = df['Consequences of the attack'].str.replace('pregnent','pregnant')
df['Consequences of the attack'] = df['Consequences of the attack'].str.replace('dearth','death')
df['Consequences of the attack'] = df['Consequences of the attack'].str.replace('mantally ill','mentally ill')

# %%
df['Consequences of the attack'].unique()
# Out:
# array(['physical injury', 'mentally ill', 'murder', 'pregnant', 'death',
#        'muder', nan], dtype=object)

# %%
df['Type of Attack'].unique()
# Out:
# array(['Child ', 'Gang', 'Opportunist', 'Child', 'Oppurtunist',
#        'Opporunist', 'Marital', 'child', 'women', 'opportunist', 'gang',
#        nan, 'Minor', '15', 'Gang '], dtype=object)

# %%
df['Type of Attack'] = df['Type of Attack'].str.lower()
df['Type of Attack'] = df['Type of Attack'].str.strip()

# %%
df[df['Type of Attack'] == 'women']
# Out:
#     Reference number                           Description of Incidents  \
# 875       TW05LI57SH  43 years old Ranjit Thami  was arrested by pol...
#
#     Type of Attack Attempted or Raped Who was it reported to  \
# 875          women               Rape                 Police
#
#     Consequences of the attack Date of Incident  Districts  \
# 875            physical injury       11/01/2020  Kathmandu
#
#                        Geographical Region Sources
# 875  27.724898979916542, 85.32441373802415     NaN

# %%
df['Type of Attack'] = df['Type of Attack'].str.replace('oppurtunist','opportunist')
df['Type of Attack'] = df['Type of Attack'].str.replace('opporunist','opportunist')
df['Type of Attack'] = df['Type of Attack'].str.replace('15','minor')
df['Type of Attack'] = df['Type of Attack'].str.replace('child','minor')
df['Type of Attack'] = df['Type of Attack'].str.replace('women','opportunist')

# %%
df['Type of Attack'].unique()
# Out:
# array(['minor', 'gang', 'opportunist', 'marital', nan], dtype=object)

# %%
df.rename(columns = {'Who was it reported to':'Reported To'}, inplace = True)

# %%
df['Reported To'] = df['Reported To'].str.lower()
df['Reported To'] = df['Reported To'].str.strip()

# %%
df[df['Reported To']=='his wife']
# Out:
#     Reference number                           Description of Incidents  \
# 202       GE82AS74UU  Police had arrested a man of around 35 year ol...
#
#     Type of Attack Attempted or Raped Reported To Consequences of the attack  \
# 202          minor              Raped    his wife            physical injury
#
#     Date of Incident Districts                    Geographical Region  \
# 202       18/11/2015    Salyan  28.442069207944435, 82.17124991675479
#
#                 Sources
# 202  nepalpolice.gov.np

# %%
df['Reported To'].unique()
# Out:
# array(['victim father', 'police', 'victim', 'family', 'victim family',
#        'neighbours', 'neighbors', 'victim mother', 'victim relatives',
#        'in-law of victim', 'victims mother', 'victims family',
#        'victim side', 'his wife', 'victim’s relatives', 'victim raletive',
#        'victim parents', 'victim raletives', 'victim relative',
#        'victim’s family', 'her father’s sister', 'victim’s mother',
#        'victim’s father', "victim's grandmother", "victim's family",
#        'father-in-law', 'wife', "victim's mother", "victim's parents",
#        "victims's mother", "victim's neighbors", "victim's son",
#        "chairperson of women's security home", 'locals',
#        "victim's brother", 'relatives', "victim's father",
#        "victim's party", 'girl', "victim's side", 'victim aunt',
#        "victim's relatives", 'victim’s parents', 'victim’s side',
#        "victim's relative", "victim's uncle", nan, "victm's mother",
# ...

# %%
df['Reported To'] = df['Reported To'].str.replace('victim father','father')
df['Reported To'] = df['Reported To'].str.replace('victim family','family')
df['Reported To'] = df['Reported To'].str.replace('neighbors','neighbours')
df['Reported To'] = df['Reported To'].str.replace('victim mother','mother')
df['Reported To'] = df['Reported To'].str.replace('victims family','family')
df['Reported To'] = df['Reported To'].str.replace('victim side','victim')
df['Reported To'] = df['Reported To'].str.replace('his wife','wife')
df['Reported To'] = df['Reported To'].str.replace('victim’s relatives','relatives')
df['Reported To'] = df['Reported To'].str.replace('victim raletive','relatives')
df['Reported To'] = df['Reported To'].str.replace('victim raletives','relatives')
df['Reported To'] = df['Reported To'].str.replace('victim parents','parents')
df['Reported To'] = df['Reported To'].str.replace('victim relative','relatives')
df['Reported To'] = df['Reported To'].str.replace('victim relative','relatives')
df['Reported To'] = df['Reported To'].str.replace('victim relative','relatives')
df['Reported To'] = df['Reported To'].str.replace('her father’s sister','relatives')
df['Reported To'] = df['Reported To'].str.replace('victim’s mother','mother')
df['Reported To'] = df['Reported To'].str.replace('victim’s father','father')
df['Reported To'] = df['Reported To'].str.replace('victim\'s grandmother','grandmother')
df['Reported To'] = df['Reported To'].str.replace('victim\'s family','family')
df['Reported To'] = df['Reported To'].str.replace('victim\'s mother','mother')
df['Reported To'] = df['Reported To'].str.replace('victim\'s parents','parents')
df['Reported To'] = df['Reported To'].str.replace('victims\'s mother','mother')
df['Reported To'] = df['Reported To'].str.replace('victim\'s neighbors','neighbours')
df['Reported To'] = df['Reported To'].str.replace('victim\'s son','son')
df['Reported To'] = df['Reported To'].str.replace('chairperson of women\'s security home','security home')
df['Reported To'] = df['Reported To'].str.replace('victim\'s brother','brother')
df['Reported To'] = df['Reported To'].str.replace('victim\'s father','father')
df['Reported To'] = df['Reported To'].str.replace('victim\'s party','party')
df['Reported To'] = df['Reported To'].str.replace('victim’s parents','parents')
df['Reported To'] = df['Reported To'].str.replace('victm\'s mother','mother')
df['Reported To'] = df['Reported To'].str.replace('victim\'s famaly','family')
df['Reported To'] = df['Reported To'].str.replace('insec and other organizations','organizations')
df['Reported To'] = df['Reported To'].str.replace('victim\'s side','victim')
df['Reported To'] = df['Reported To'].str.replace('vctim\'s side','victim')
df['Reported To'] = df['Reported To'].str.replace('victims father','father')
df['Reported To'] = df['Reported To'].str.replace('victim\'s relatives','relatives')
df['Reported To'] = df['Reported To'].str.replace('victim\'s side.','victim')
df['Reported To'] = df['Reported To'].str.replace('victim girl\'s side','victim')
df['Reported To'] = df['Reported To'].str.replace('victim parenst','parents')
df['Reported To'] = df['Reported To'].str.replace('relativess','relatives')
df['Reported To'] = df['Reported To'].str.replace('victims mother','mother')
df['Reported To'] = df['Reported To'].str.replace('victim\'s neighbours','neighbours')
df['Reported To'] = df['Reported To'].str.replace('father-in-law','in-laws')
df['Reported To'] = df['Reported To'].str.replace('in-law of victim','in-laws')
df['Reported To'] = df['Reported To'].str.replace('victim’s family','family')
df['Reported To'] = df['Reported To'].str.replace('victim.','victim')
# Out:
# C:\Users\Bishesh Kafle\AppData\Local\Temp\ipykernel_13940\3900718067.py:37: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Reported To'] = df['Reported To'].str.replace('victim\'s side.','victim')
# C:\Users\Bishesh Kafle\AppData\Local\Temp\ipykernel_13940\3900718067.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Reported To'] = df['Reported To'].str.replace('victim.','victim')

# %%
df['Reported To'].unique()
# Out:
# array(['father', 'police', 'victim', 'family', 'neighbours', 'mother',
#        'relatives', 'in-laws', 'wife', 'parents', 'grandmother', 'son',
#        'security home', 'locals', 'brother', 'party', 'girl',
#        'victimaunt', 'victims side', 'victims relative', 'victims uncle',
#        nan, 'organizations'], dtype=object)

# %%
df['Attempted or Raped'].unique()
# Out:
# array(['Molesting', 'Attempted', 'Raped', 'Assulting ', 'Molesting ',
#        'Sexually Abusing ', 'Assaulted ', 'Attemed', 'Attemped',
#        'sexual assault ', ' sexually abusing ', ' sexually harassing',
#        'molesting ', ' sexually abusing', 'sexually assaulting ',
#        'sexually harassing', ' sexual voilance', 'Sexual Harrassment',
#        'Molestation', 'Sexual abuse', 'Raped and killed', 'Rape', 'Both',
#        nan, 'Sexually Abusing', 'Sexually Abused', 'Sexually harassing',
#        'sexually Abusing', 'assaulting', 'Marital Rape',
#        'Sexually Harassment', 'Assaulted', 'Minor', 'Sexually Assault ',
#        'Raped ', 'Sexually abused', 'Sexually Assaulted',
#        'Attempted rape', 'Sexually harassed', 'Sexually assaulted',
#        'Harrassed', 'Attempted ', 'Abused', 'sexually assaulting',
#        'Sexually assulted', 'ATtempted', 'Sexually assaulted '],
#       dtype=object)

# %%
df['Attempted or Raped'] = df['Attempted or Raped'].str.lower()
df['Attempted or Raped'] = df['Attempted or Raped'].str.strip()

# %%
df['Attempted or Raped'].unique()
# Out:
# array(['molesting', 'attempted', 'raped', 'assulting', 'sexually abusing',
#        'assaulted', 'attemed', 'attemped', 'sexual assault',
#        'sexually harassing', 'sexually assaulting', 'sexual voilance',
#        'sexual harrassment', 'molestation', 'sexual abuse',
#        'raped and killed', 'rape', 'both', nan, 'sexually abused',
#        'assaulting', 'marital rape', 'sexually harassment', 'minor',
#        'sexually assault', 'sexually assaulted', 'attempted rape',
#        'sexually harassed', 'harrassed', 'abused', 'sexually assulted'],
#       dtype=object)

# %%
df[df['Attempted or Raped']=='sexual voilance']
# Out:
#     Reference number                           Description of Incidents  \
# 458       LC26FI16DH  A special team of police despatched to monitor...
#
#     Type of Attack Attempted or Raped Reported To Consequences of the attack  \
# 458    opportunist    sexual voilance      police            physical injury
#
#     Date of Incident  Districts                    Geographical Region  \
# 458       04/08/2017  Kathmandu  27.727026303889943, 85.32372709254854
#
#                 Sources
# 458  nepalpolice.gov.np

# %%
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('assulting','assault')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('attemed','attempt')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('sexually abusing','abuse')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('molesting','molestation')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('attemped','attempt')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('sexually harassing','harassment')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('sexually assaulting','assault')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('sexual voilance','harassment')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('sexual harrassment','harassment')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('sexual abuse','abuse')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('raped and killed','assault')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('rape','assault')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('sexually abused','abuse')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('assaulting','assault')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('sexually harassment','harassment')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('minor','assault')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('sexually assault','assault')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('sexually assaulted','assault')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('attempted rape','attempt')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('sexually harassed','harassment')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('harrassed','harassment')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('abused','abuse')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('sexually assulted','assault')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('assultd','assault')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('sexual assault','assault')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('attempted assault','assault')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('assaulted','assault')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('assaultd','assault')
df['Attempted or Raped'] = df['Attempted or Raped'].str.replace('attempted','attempt')

# %%
df['Attempted or Raped'].unique()
# Out:
# array(['molestation', 'attempt', 'assault', 'abuse', 'harassment', 'both',
#        nan, 'marital assault'], dtype=object)

# %%
df["Districts"].unique()
# Out:
# array(['Kathmandu', 'Siraha', 'Jhapa', 'Rautahat', 'Mahottari', 'sunsari',
#        'Rupandehi', 'Morang', 'Sindhupalchowk', 'Khotang', 'Rukum',
#        'Palpa', 'Lamjung', 'Gulmi', 'Kaverepalanchowk', 'Kaski', 'Banke',
#        'Kavrepalanchock', 'Bara', 'Bhaktapur', 'Pyuthan',
#        'Kaverepalanchok', 'Sarlahi', 'Bhojpur', 'Sunsari', 'Terhathum',
#        'Dang', 'Syangja', 'Kailali', 'Kanchanpur', 'Gorkha', 'Dadeldhura',
#        'Dhanusa', 'Kavrepalanchok', 'Panchthar', 'Sindhuli', 'Tanahu',
#        'Udayapur', 'Makwanpur', 'Ilam', 'Rasuwa', 'Kapilvastu', 'Baglung',
#        'Bardiya', 'Sindhupalchok', 'Jajarkot', 'Lalitpur', 'Dailekh',
#        'Myagdi', 'Arghakhanchi', 'Taplejung', 'Dolakha', 'Nawalparasi',
#        'Darchula', 'Salyan', 'Surkhet', 'Parsa', 'Parbat', 'Saptari',
#        'Panchathar', 'Kalikot', 'Dhanusha', 'Chitwan', 'Mohattari',
#        'Baitadi', 'Bajura', 'Nuwakot', 'Bajhang', 'Sunsary', 'Jumla',
# ...

# %%
df
# Out:
#      Reference number                           Description of Incidents  \
# 0          CH14QV99NQ  An 18-year-old youth was arrested March 25 on ...
# 1          XJ99BF74EC  Police had taken under control Hitman Shahi (4...
# 2          IG49WH92XY  Fourteen year old Devendra Rana and eleven yea...
# 3          IS62NJ41RL  Police on 07 May arrested Dharmaraj Jamarkatte...
# 4          ZP39BS50LY  Police on 08 May arrested Bhakta Bahadur Blon ...
# ...               ...                                                ...
# 2415       VQ02QJ16IA  One person has been arrested on charges of rap...
# 2416       OS92RX27HN  Baglung, a 17-year-old boy living in Nisikhola...
# 2417       LW75CB63DB  Jhapa, 31-year-old Dhan Kumar Limbu, resident ...
# 2418       KH48LW89IO  Baglung, Police arrested 28-year-old Bimal Ham...
# 2419       HH53FD93DS  Man arrested from Sankhuwasabha on the charge ...
#
#      Type of Attack Attempted or Raped Reported To Consequences of the attack  \
# ...

# %%
df["Districts"]=df["Districts"].str.lower()
df["Districts"]=df["Districts"].str.strip()
df["Districts"]=df["Districts"].str.replace("kaverepalanchowk","kavrepalanchok")
df["Districts"]=df["Districts"].str.replace("sunsary","sunsari")
df["Districts"]=df["Districts"].str.replace("rupendhi","rupandehi")
df["Districts"]=df["Districts"].str.replace("terahathum","terhathum")
df["Districts"]=df["Districts"].str.replace("solukhubmu","solukhumbu")
df["Districts"]=df["Districts"].str.replace("tehrathum","terhathum")
df["Districts"]=df["Districts"].str.replace("terathum","terhathum")
df["Districts"]=df["Districts"].str.replace("rupandahi","rupandehi")
df["Districts"]=df["Districts"].str.replace("rupandhi","rupandehi")
df["Districts"]=df["Districts"].str.replace("sindupalchok","sindhupalchowk")
df["Districts"]=df["Districts"].str.replace("sindupalchowk","sindhupalchowk")
df["Districts"]=df["Districts"].str.replace("sindhupalachok","sindhupalchowk")
df["Districts"]=df["Districts"].str.replace("sindhhupalchok","sindhupalchowk")
df["Districts"]=df["Districts"].str.replace("sindhupalchok","sindhupalchowk")
df["Districts"]=df["Districts"].str.replace("sindhuplchwok","sindhupalchowk")
df["Districts"]=df["Districts"].str.replace("sindhuplchowk","sindhupalchowk")
df["Districts"]=df["Districts"].str.replace("sindhupalchwok","sindhupalchowk")
df["Districts"]=df["Districts"].str.replace("mohattari","mahottari")
df["Districts"]=df["Districts"].str.replace("ruoendehi","rupandehi")
df["Districts"]=df["Districts"].str.replace("rupendehi","rupandehi")
df["Districts"]=df["Districts"].str.replace("western rukum","rukum")
df["Districts"]=df["Districts"].str.replace("rukum west, karnali","rukum")
df["Districts"]=df["Districts"].str.replace("rukum \(west\)","rukum")
df["Districts"]=df["Districts"].str.replace("rukum west","rukum")
df["Districts"]=df["Districts"].str.replace("rukum east","rukum")
df["Districts"]=df["Districts"].str.replace("kabhrepalanchok","kavre")
df["Districts"]=df["Districts"].str.replace("kavrepalanchock","kavre")
df["Districts"]=df["Districts"].str.replace("kaverepalanchok","kavre")
df["Districts"]=df["Districts"].str.replace("kavrepalanchok","kavre")
df["Districts"]=df["Districts"].str.replace("bhojur","bhojpur")
df["Districts"]=df["Districts"].str.replace("sayangja","syangja")
df["Districts"]=df["Districts"].str.replace("sayanja","syangja")
df["Districts"]=df["Districts"].str.replace("panchathar","panchthar")
df["Districts"]=df["Districts"].str.replace("pachthar","panchthar")
df["Districts"]=df["Districts"].str.replace("tahanu","tanahu")
df["Districts"]=df["Districts"].str.replace("tanahun","tanahu")
df["Districts"]=df["Districts"].str.replace("udhayapur","udayapur")
df["Districts"]=df["Districts"].str.replace("udaypur","udayapur")
df["Districts"]=df["Districts"].str.replace("udaipur","udayapur")
df["Districts"]=df["Districts"].str.replace("ilam","illam")
df["Districts"]=df["Districts"].str.replace("kapilbastu","kapilvastu")
df["Districts"]=df["Districts"].str.replace("bardia","bardiya")
df["Districts"]=df["Districts"].str.replace("dailekh","dailekh")
df["Districts"]=df["Districts"].str.replace("taplegunj","taplejung")
df["Districts"]=df["Districts"].str.replace("dolkha","dolakha")
df["Districts"]=df["Districts"].str.replace("nawaparasi west","nawalparasi")
df["Districts"]=df["Districts"].str.replace("nawalparasi west","nawalparasi")
df["Districts"]=df["Districts"].str.replace("nawalparasi east","nawalparasi")
df["Districts"]=df["Districts"].str.replace("pratappur","nawalparasi")
df["Districts"]=df["Districts"].str.replace("sapatari","saptari")
df["Districts"]=df["Districts"].str.replace("chitawan","chitwan")
df["Districts"]=df["Districts"].str.replace("solukhumbhu","solukhumbu")
df["Districts"]=df["Districts"].str.replace("solukhubmu","solukhumbu")
df["Districts"]=df["Districts"].str.replace("shankhuwasabha","sankhuwasabha")
df["Districts"]=df["Districts"].str.replace("bakya","banke")
df["Districts"]=df["Districts"].str.replace("rampur, palpa","palpa")
df["Districts"]=df["Districts"].str.replace("gandaki, parbat","parbat")
df["Districts"]=df["Districts"].str.replace("gandaki, myagdi","myagdi")
df["Districts"]=df["Districts"].str.replace("karnali, dailekh","dailekh")
df["Districts"]=df["Districts"].str.replace("mades,bara","bara")
df["Districts"]=df["Districts"].str.replace("kritipur","kathmandu")
df["Districts"]=df["Districts"].str.replace("okheldunga","okhaldhunga")
df["Districts"]=df["Districts"].str.replace("mades,bara","bara")
df["Districts"]=df["Districts"].str.replace("birgunj","parsa")
df["Districts"]=df["Districts"].str.replace("hetauda","makwanpur")
df["Districts"]=df["Districts"].str.replace("pokhara","kaski")
df["Districts"]=df["Districts"].str.replace("itahari","sunsari")
df["Districts"]=df["Districts"].str.replace("lumbini","rupandehi")
df["Districts"]=df["Districts"].str.replace("dharan","sunsari")
df["Districts"]=df["Districts"].str.replace("bardibas","mahottari")
df["Districts"]=df["Districts"].str.replace("dhanusha","dhanusa")
df["Districts"]=df["Districts"].str.replace("madi","chitwan")
# Out:
# C:\Users\Bishesh Kafle\AppData\Local\Temp\ipykernel_13940\2300343643.py:25: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["Districts"]=df["Districts"].str.replace("rukum \(west\)","rukum")

# %%
len(df['Districts'].unique())
# Out:
# 85

# %%
df.dropna(inplace = True)

# %%
df = df.reset_index()
df = df.drop('index',axis = 1)

# %%
df.to_csv('cleandata.csv')
